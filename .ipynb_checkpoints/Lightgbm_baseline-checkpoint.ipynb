# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors
import csv
import json
import os
import xgboost.sklearn as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import accuracy_score
import lightgbm as lgb
from lightgbm import LGBMClassifier

# %%
#从文件load到numpy array
data_dir = 'preprocessed_add_diff'
#读入service_type==1的训练数据
x_train_1 = np.load(os.path.join(data_dir,'x_train_1.npy'))
x_validation_1 = np.load(os.path.join(data_dir,'x_validation_1.npy'))
y_train_1 = np.load(os.path.join(data_dir,'y_train_1.npy'))
y_validation_1 = np.load(os.path.join(data_dir,'y_validation_1.npy'))

#读入测试数据
x_test = np.load(os.path.join(data_dir,'x_test.npy'))

csv_file = csv.reader(open('preprocessed/id_all_test.csv','r'))
id_test = []
for line in csv_file:
    id_test.append(line[0])

print(x_test[0])
print(id_test[0])
# Out:
# [ 1.00000000e+00  0.00000000e+00  1.80000000e+01  5.04000000e+01
#   1.08200000e+02  1.18900000e+02  1.77700000e+02  3.00000000e+02
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   4.00000000e+00  2.00000000e+00  6.00000000e+01  0.00000000e+00
#   2.63908486e+03  3.77833333e+01  3.77833333e+01  0.00000000e+00
#   1.00000000e+00  1.90000000e+01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -5.78000000e+01 -1.07000000e+01
#  -5.88000000e+01  9.60000000e+00  3.00000000e+02  8.71930804e-02
#   1.13800000e+02  1.77700000e+02  5.04000000e+01  3.77833333e+01
#   0.00000000e+00  1.00000000e+00  2.93908486e+03  1.02072589e-01
#   0.00000000e+00  4.47325000e+01  5.04000000e+01 -3.96000000e+01]
# 012pSke7DsCrR985
# 0
# 0
# 1
# 5

# %%
cat_cols = ['contract_type', 'net_service', 'gender', 'complaint_level',       
   'is_mix_service',  'many_over_bill', 'is_promise_low_consume',     
    ]
all_cols = ['is_mix_service', 'online_time', '1_total_fee',
       '2_total_fee', '3_total_fee', '4_total_fee', 'month_traffic',
       'many_over_bill', 'contract_type', 'contract_time',
       'is_promise_low_consume', 'net_service', 'pay_times', 'pay_num',
       'last_month_traffic', 'local_trafffic_month', 'local_caller_time',
       'service1_caller_time', 'service2_caller_time', 'gender', 'age',
       'complaint_level', 'former_complaint_num', 'former_complaint_fee',
       'is_final','diff_total_fee_1', 'diff_total_fee_2', 'diff_total_fee_3',
       'pay_num_1_total_fee', 'last_month_traffic_rest', 'rest_traffic_ratio',
       'total_fee_mean', 'total_fee_max', 'total_fee_min', 'total_caller_time',
       'service2_caller_ratio', 'local_caller_ratio', 'total_month_traffic',
       'month_traffic_ratio', 'last_month_traffic_ratio',
       '1_total_fee_call_fee', '1_total_fee_call2_fee',
       '1_total_fee_trfc_fee',
       #'count_1_total_fee','count_2_total_fee','count_3_total_fee',
       # 'count_4_total_fee','count_former_complaint_fee','count_pay_num',
       # 'count_contract_time','count_last_month_traffic','count_online_time'
        ]
num_features = len(x_test[0]) + 1
print("num_features:",num_features)
# Out:
# num_features: 44

# %%
from sklearn.metrics import f1_score
targetlabel_1 = [0, 1, 2]

def evalerror(preds, lgtrain):
    preds = np.argmax(preds.reshape(3, -1),axis=0)
    y_true = lgtrain.get_label()
    result = f1_score(y_true,preds,average = 'macro')
    return 'f1_score',result,True


import lightgbm as lgb
lgb_train = lgb.Dataset(x_train_1,label = y_train_1,feature_name=all_cols, categorical_feature = cat_cols)
lgb_eval = lgb.Dataset(x_validation_1,label = y_validation_1,feature_name=all_cols, categorical_feature = cat_cols)

print("begin build")        
params = {
            'task': 'train',
            'boosting_type': 'gbdt',
            'objective': 'regression',
            'num_class':3,
            #'max_depth': 8,
            'num_leaves': 120,
            'lambda_l1' : 0,
            'lambda_l2':0.,
            'learning_rate': 0.03,
            'feature_fraction': 0.5,
            'bagging_fraction': 0.9,
            'bagging_freq': 1,
            'verbose': 0,
            'bagging_seed' :2018,
            'feature_fraction_seed':2018,
            #'seed': 66,
            'num_threads' : -1,
            'metric': 'multi_error',
         }
print("begin fit")    
model_1 = lgb.train(params,
                    lgb_train,
                    num_boost_round=800,
                    valid_sets=lgb_eval,
                    verbose_eval=10,
                    feval=evalerror,
                    early_stopping_rounds=100,
                   )
# Out:
# begin build
# begin fit
# Training until validation scores don't improve for 100 rounds.
# [10]	valid_0's multi_error: 0.00632584	valid_0's f1_score: 0.98141
# [20]	valid_0's multi_error: 0.00605006	valid_0's f1_score: 0.982241
# [30]	valid_0's multi_error: 0.00603282	valid_0's f1_score: 0.982314
# [40]	valid_0's multi_error: 0.00589493	valid_0's f1_score: 0.982735
# [50]	valid_0's multi_error: 0.0057398	valid_0's f1_score: 0.983174
# [60]	valid_0's multi_error: 0.00565361	valid_0's f1_score: 0.983421
# [70]	valid_0's multi_error: 0.00556743	valid_0's f1_score: 0.983679
# [80]	valid_0's multi_error: 0.00548125	valid_0's f1_score: 0.983881
# [90]	valid_0's multi_error: 0.00527441	valid_0's f1_score: 0.984482
# [100]	valid_0's multi_error: 0.0050848	valid_0's f1_score: 0.985014
# [110]	valid_0's multi_error: 0.00498138	valid_0's f1_score: 0.985238
# [120]	valid_0's multi_error: 0.00491244	valid_0's f1_score: 0.985444
# [130]	valid_0's multi_error: 0.00482625	valid_0's f1_score: 0.985686
# [140]	valid_0's multi_error: 0.00472284	valid_0's f1_score: 0.985954
# [150]	valid_0's multi_error: 0.00461942	valid_0's f1_score: 0.98623
# [160]	valid_0's multi_error: 0.00444705	valid_0's f1_score: 0.986743
# [170]	valid_0's multi_error: 0.00441258	valid_0's f1_score: 0.986849
# [180]	valid_0's multi_error: 0.00430916	valid_0's f1_score: 0.987097
# [190]	valid_0's multi_error: 0.00429192	valid_0's f1_score: 0.987178
# [200]	valid_0's multi_error: 0.00417126	valid_0's f1_score: 0.987553
# [210]	valid_0's multi_error: 0.00411955	valid_0's f1_score: 0.9877
# [220]	valid_0's multi_error: 0.00405061	valid_0's f1_score: 0.987891
# [230]	valid_0's multi_error: 0.0039989	valid_0's f1_score: 0.988057
# [240]	valid_0's multi_error: 0.00389548	valid_0's f1_score: 0.988333
# [250]	valid_0's multi_error: 0.00389548	valid_0's f1_score: 0.988339
# [260]	valid_0's multi_error: 0.00387824	valid_0's f1_score: 0.988393
# [270]	valid_0's multi_error: 0.00387824	valid_0's f1_score: 0.98839
# [280]	valid_0's multi_error: 0.00380929	valid_0's f1_score: 0.988597
# [290]	valid_0's multi_error: 0.003861	valid_0's f1_score: 0.988455
# [300]	valid_0's multi_error: 0.00375758	valid_0's f1_score: 0.988733
# [310]	valid_0's multi_error: 0.00374035	valid_0's f1_score: 0.988787
# [320]	valid_0's multi_error: 0.00377482	valid_0's f1_score: 0.988663
# [330]	valid_0's multi_error: 0.00379206	valid_0's f1_score: 0.988608
# [340]	valid_0's multi_error: 0.00379206	valid_0's f1_score: 0.988633
# [350]	valid_0's multi_error: 0.00382653	valid_0's f1_score: 0.988527
# [360]	valid_0's multi_error: 0.00379206	valid_0's f1_score: 0.98863
# [370]	valid_0's multi_error: 0.00377482	valid_0's f1_score: 0.988684
# [380]	valid_0's multi_error: 0.00370587	valid_0's f1_score: 0.988896
# [390]	valid_0's multi_error: 0.00368864	valid_0's f1_score: 0.988948
# [400]	valid_0's multi_error: 0.00368864	valid_0's f1_score: 0.988948
# [410]	valid_0's multi_error: 0.00370587	valid_0's f1_score: 0.988894
# [420]	valid_0's multi_error: 0.00370587	valid_0's f1_score: 0.988891
# [430]	valid_0's multi_error: 0.00372311	valid_0's f1_score: 0.988836
# [440]	valid_0's multi_error: 0.00372311	valid_0's f1_score: 0.988836
# [450]	valid_0's multi_error: 0.00368864	valid_0's f1_score: 0.988945
# [460]	valid_0's multi_error: 0.00370587	valid_0's f1_score: 0.988888
# [470]	valid_0's multi_error: 0.0036714	valid_0's f1_score: 0.988973
# Early stopping, best iteration is:
# [374]	valid_0's multi_error: 0.0036714	valid_0's f1_score: 0.989005

# %%
plt.figure(figsize=(12,6))
lgb.plot_importance(model_1, max_num_features=60)
plt.title("Featurertances")
plt.show()

### make prediction for test data
y_predicted_1_prob = model_1.predict(x_validation_1, num_iteration=model_1.best_iteration)

y_predicted_1 = np.argmax(y_predicted_1_prob,axis = 1)   #转化为类别

accuracy_1 = accuracy_score(y_validation_1, y_predicted_1)
print("Accuracy: %.2f%%" % (accuracy_1 * 100.0))

from sklearn.metrics import f1_score
 
targetlabel_1 = [0, 1, 2]
score_1 = f1_score(y_validation_1, y_predicted_1, labels = targetlabel_1,average='macro')
score_1_array = f1_score(y_validation_1, y_predicted_1, labels = targetlabel_1,average=None)
print(score_1)
print(label_1)
print(score_1_array)
# Out:
# Accuracy: 99.63%
# 0.9890052440957926
# {90063345: 0, 90109916: 1, 90155946: 2}
# [0.99792049 0.9967903  0.97230494]

# %%
#plt.figure(figsize=(15,15))
#lgb.plot_importance(model_4,height=0.5, max_num_features=90)
#plt.title("Featurertances")
#plt.show()
fig_1,ax_1 = plt.subplots(figsize=(15,15))
lgb.plot_importance(model_1,
                height=0.5,
                ax=ax_1,
                max_num_features=90)
plt.show()

# %%
### make prediction for test data
import warnings
warnings.filterwarnings("ignore")
y_predicted_test = []
line_predicted = []
result_label =0
temp = 0
dict_label_1 = {0:90063345,1:90109916, 2:90155946}
dict_label_4 = {0:89950168,1:89950166, 2:99999828,3: 99999827, 4:99999830, 5:89950167,6: 99999826, 7:99999825}
print("begin predict")
y_predicted_test_1_prob = model_1.predict(x_test[:,1:num_features], num_iteration=model_1.best_iteration)
y_predicted_test_1 = np.argmax(y_predicted_test_1_prob,axis = 1)   #转化为类别
y_predicted_test_4_prob = model_4.predict(x_test[:,1:num_features], num_iteration=model_4.best_iteration) 
y_predicted_test_4 = np.argmax(y_predicted_test_4_prob,axis = 1)   #转化为类别
index = 0
for line in x_test:
    if (line[0]==1):
        line_predicted = dict_label_1[y_predicted_test_1[index]]
    elif (line[0]==4):
        line_predicted = dict_label_4[y_predicted_test_4[index]]
    else:
        line_predicted = dict_label_4[y_predicted_test_4[index]]
    y_predicted_test.append(line_predicted)
    index += 1
print(y_predicted_test[0])
# Out:
# begin predict
# 90063345

# %%
print(x_test[0][1])
print(x_test[1])
print(x_test[2])
# Out:
# 0.0
# [ 1.00000000e+00  0.00000000e+00  1.60000000e+01  8.44000000e+01
#   7.82000000e+01  5.69000000e+01  8.04000000e+01  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   4.00000000e+00  3.00000000e+00  9.00000000e+01  0.00000000e+00
#   3.91554587e+04  5.18333333e+00  4.18333333e+01  0.00000000e+00
#   1.00000000e+00  2.00000000e+01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  6.20000000e+00  2.13000000e+01
#  -2.35000000e+01  5.60000000e+00  0.00000000e+00  0.00000000e+00
#   7.49750000e+01  8.44000000e+01  5.69000000e+01  4.18333333e+01
#   0.00000000e+00  1.23904382e-01  3.91554587e+04  0.00000000e+00
#   0.00000000e+00  7.81250000e+01  8.44000000e+01  8.44000000e+01]
# [ 1.00000000e+00  0.00000000e+00  9.00000000e+00  8.05000000e+01
#   7.56000000e+01  7.43000000e+01  9.34000000e+01  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   4.00000000e+00  4.00000000e+00  7.00000000e+01  0.00000000e+00
#   4.87559501e+04  6.38666667e+01  6.76666667e+01  0.00000000e+00
#   1.00000000e+00  1.80000000e+01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  4.90000000e+00  1.30000000e+00
#  -1.91000000e+01 -1.05000000e+01  0.00000000e+00  0.00000000e+00
#   8.09500000e+01  9.34000000e+01  7.43000000e+01  6.76666667e+01
#   0.00000000e+00  9.43842365e-01  4.87559501e+04  0.00000000e+00
#   0.00000000e+00  7.03500000e+01  8.05000000e+01  8.05000000e+01]

# %%
header = [('user_id','current_service')]

with open('lgb_44_10_submission.csv', 'w') as f:
    writer = csv.writer(f,lineterminator='\n')
    writer.writerows(header)
    for i in range(len(id_test)):
        writer.writerows([(id_test[i],y_predicted_test[i])])

print('done')
# Out:
# done

# %%
#保存成python支持的文件格式pickle
import pickle
with open('LGB.pickle', 'wb') as fw:
    pickle.dump(estimator, fw)
    
## 如需加载.pickle
#with open('deci.pickle', 'rb') as fr:
#    new_estimator = pickle.load(fr)
#    print new_estimator.predict(x_test)
